# %% [markdown]
# #Task2: Try Linear regression on same prediction data using Tensorflow

# %%
import numpy as np
import tensorflow as tf

# %%
inputs = np.array([[73, 67, 43], [91, 88, 64], [87, 134, 58], [102, 43, 37], [69, 96, 70],[73, 67, 43], [91, 88, 64], 
                   [87, 134, 58], [102, 43, 37], [69, 96, 70], [73, 67, 43], [91, 88, 64], [87, 134, 58], [102, 43, 37], 
                   [69, 96, 70]], dtype='float64')

targets = np.array([[56, 70], [81, 101], [119, 133], [22, 37], [103, 119],[56, 70], [81, 101], [119, 133], [22, 37], 
                    [103, 119],[56, 70], [81, 101], [119, 133], [22, 37], [103, 119]], dtype='float64')

# %%
inputs = tf.Variable(inputs)
targets = tf.Variable(targets)
print("targets :\n",targets)
# Out:
# targets :
#  <tf.Variable 'Variable:0' shape=(15, 2) dtype=float64, numpy=
# array([[ 56.,  70.],
#        [ 81., 101.],
#        [119., 133.],
#        [ 22.,  37.],
#        [103., 119.],
#        [ 56.,  70.],
#        [ 81., 101.],
#        [119., 133.],
#        [ 22.,  37.],
#        [103., 119.],
#        [ 56.,  70.],
#        [ 81., 101.],
#        [119., 133.],
#        [ 22.,  37.],
#        [103., 119.]])>

# %%
v = np.random.rand(3,2)
r = np.random.randn(2)
v = tf.Variable(v)
r = tf.Variable(r)

print(v)
print("\n",r)
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[0.32244311, 0.25699055],
#        [0.40752076, 0.75664355],
#        [0.47513931, 0.41085399]])>
#
#  <tf.Variable 'Variable:0' shape=(2,) dtype=float64, numpy=array([1.46342069, 0.79998223])>

# %%
def model(s):
    return s @ v + r

# %%
prediction = model(inputs)
print(prediction)
# Out:
# tf.Tensor(
# [[ 72.73664909  87.92213238]
#  [ 97.0764866  117.06541083]
#  [111.6818332  148.37792815]
#  [ 69.45616517  74.75028909]
#  [ 96.09374014 119.9298911 ]
#  [ 72.73664909  87.92213238]
#  [ 97.0764866  117.06541083]
#  [111.6818332  148.37792815]
#  [ 69.45616517  74.75028909]
#  [ 96.09374014 119.9298911 ]
#  [ 72.73664909  87.92213238]
#  [ 97.0764866  117.06541083]
#  [111.6818332  148.37792815]
#  [ 69.45616517  74.75028909]
#  [ 96.09374014 119.9298911 ]], shape=(15, 2), dtype=float64)

# %%
def mse(t1,t2):
    return tf.reduce_mean(tf.square(t1 - t2))
print(mse(prediction,targets))
# Out:
# tf.Tensor(513.3638399441487, shape=(), dtype=float64)

# %%
epochs = 40
for epoch_count in range(epochs):
    
    with tf.GradientTape(persistent=True) as t:
        current_loss = mse(targets, model(inputs))

    v1 = t.gradient(current_loss,v)
    r1 = t.gradient(current_loss,r)

    v.assign_sub(1e-4 * v1)
    r.assign_sub(1e-4 * r1)
        
    print(f" \n Epoch count: {epoch_count} \n Loss value: {current_loss.numpy()}")
# Out:
#
#  Epoch count: 0
#  Loss value: 513.3638399441487
#
#  Epoch count: 1
#  Loss value: 404.6171502114876
#
#  Epoch count: 2
#  Loss value: 326.9728324879377
#
#  Epoch count: 3
#  Loss value: 269.9540596286428
#
#  Epoch count: 4
#  Loss value: 226.86350182606267
#
#  Epoch count: 5
#  Loss value: 193.3858132845565
#
#  Epoch count: 6
#  Loss value: 166.71120133670405
#
#  Epoch count: 7
#  Loss value: 144.98524663421944
#
#  Epoch count: 8
#  Loss value: 126.96305631059292
#
#  Epoch count: 9
#  Loss value: 111.79145022988595
#
#  Epoch count: 10
#  Loss value: 98.87142249444064
#
#  Epoch count: 11
#  Loss value: 87.77097923871523
#
#  Epoch count: 12
#  Loss value: 78.1696288464653
#
#  Epoch count: 13
#  Loss value: 69.82279418577794
#
#  Epoch count: 14
#  Loss value: 62.53879359996093
#
#  Epoch count: 15
#  Loss value: 56.16377752711025
#
#  Epoch count: 16
#  Loss value: 50.5717234277595
#
#  Epoch count: 17
#  Loss value: 45.65766649601547
#
#  Epoch count: 18
#  Loss value: 41.333017240917144
#
#  Epoch count: 19
#  Loss value: 37.522239506511916
#
#  Epoch count: 20
#  Loss value: 34.160427743609084
#
#  Epoch count: 21
#  Loss value: 31.19148910811276
#
#  Epoch count: 22
#  Loss value: 28.56674101118649
#
#  Epoch count: 23
#  Loss value: 26.24380110141802
#
#  Epoch count: 24
#  Loss value: 24.18568872837335
#
#  Epoch count: 25
#  Loss value: 22.36008374468216
#
#  Epoch count: 26
#  Loss value: 20.738705704006254
#
#  Epoch count: 27
#  Loss value: 19.29678764933793
#
#  Epoch count: 28
#  Loss value: 18.01262598390427
#
#  Epoch count: 29
#  Loss value: 16.86719277240735
#
#  Epoch count: 30
#  Loss value: 15.843800112281842
#
#  Epoch count: 31
#  Loss value: 14.927808497269101
#
#  Epoch count: 32
#  Loss value: 14.106372719419424
#
#  Epoch count: 33
#  Loss value: 13.368220043276828
#
#  Epoch count: 34
#  Loss value: 12.70345627970363
#
#  Epoch count: 35
#  Loss value: 12.103396078135372
#
#  Epoch count: 36
#  Loss value: 11.560414304558897
#
#  Epoch count: 37
#  Loss value: 11.067815817434534
#
#  Epoch count: 38
#  Loss value: 10.619721321418039
#
#  Epoch count: 39
#  Loss value: 10.210967287078672
